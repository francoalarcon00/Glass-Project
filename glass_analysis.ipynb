# %%
# Importamos librerias para visualización
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# Carga de datos
df = pd.read_csv('cleaned_glass.csv')

# %%
# Información general de los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   214 non-null    int64
#  1   RI      214 non-null    float64
#  2   Na      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  Type    214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p >
#     <li>Todas las variables son numéricas</li>
#     <li>El índice de refracción y el tipo son variables enteras, mientras que las demás son flotantes</li>
# </p>
# <br>

# %%
# Visualización de las columnas
df = df.drop(columns=['index'])
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %% [markdown]
# <br>
# <br>
# <h2 align="center">Data Visualization 👨‍💻​📊​ </h2>

# %% [markdown]
# <h4 align="center">Analicemos cada feature del dataset ​ </h4>

# %% [markdown]
# <br>
# <br>
# <img src='https://www.lifeder.com/wp-content/uploads/2018/06/tabla-periodica-espanol.jpg'></img>

# %% [markdown]
# <br>
# <h3 align='center'>RI: Indice de refracción 👈</h3>

# %%
# Descripción del índice de refracción y sus respectivas gráficas

description_RI = pd.DataFrame(df.RI.describe())
print('')
print(description_RI.T)
print('')
sns.set_theme(style='darkgrid')
plt.figure(figsize=(20, 10))
plt.subplot(2, 1, 1)
sns.histplot(x='RI', kde=True, data=df, bins=20, color='indianred')
plt.subplot(2, 1, 2)
sns.boxplot(x='RI', data=df, color='indianred')
plt.show()
# Out:
#     count      mean       std      min       25%      50%       75%      max
# RI  214.0  1.518365  0.003037  1.51115  1.516522  1.51768  1.519157  1.53393

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media del RI es de 1.518 unidades aproximadamente (el RI no posee unidad física).</li>
#     <br>
#     <li>La distribución posee un bajo desvío estándar (0.003 aprox), es decir, no existe una variación significativa de los datos. Sin embargo, se puede visualizar una tendencia sesgada levemente hacia la derecha tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca de los 0.152 unidades.</li>
#     <br>
#     <li>Observemos que existen varios outliers en esta variable.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Na: Sodio 👈</h3>

# %%
# Descripción del sodio y sus respectivas gráficas

description_Na = pd.DataFrame(df.Na.describe())
print('')
print(description_Na.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2, 1, 1)
sns.histplot(x='Na', kde=True, data=df, bins=20, color='darkorange')
plt.subplot(2, 1, 2)
sns.boxplot(x='Na', data=df, color='darkorange')
plt.show()
# Out:
#     count      mean       std    min      25%   50%     75%    max
# Na  214.0  13.40785  0.816604  10.73  12.9075  13.3  13.825  17.38

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 13.4 %.</li>
#     <br>
#     <li>La distribución un desvío estándar de 0.81 aprox. Se puede visualizar una tendencia sesgada levemente hacia la derecha tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 13.3 %.</li>
#     <br>
#     <li>Observemos que no hay muchos outliers en esta variable.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Mg: Magnesio 👈</h3>

# %%
# Descripción del magnesio y sus respectivas gráficas

description_Mg = pd.DataFrame(df.Mg.describe())
print('')
print(description_Mg.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2, 1, 1)
sns.histplot(x='Mg', kde=True, data=df, bins=20, color='goldenrod')
plt.subplot(2, 1, 2)
sns.boxplot(x='Mg', data=df, color='goldenrod')
plt.show()
# Out:
#     count      mean       std  min    25%   50%  75%   max
# Mg  214.0  2.684533  1.442408  0.0  2.115  3.48  3.6  4.49

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 2.68 %.</li>
#     <br>
#     <li>La distribución posee el valor de desvío estándar más alto (1.44 aprox) con respecto a las demás variables. Se puede visualizar una tendencia claramente sesgada hacia la izquierda tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 3.48 %.</li>
#     <br>
#     <li>Observemos que no hay outliers en esta variable.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Al: Aluminio 👈</h3>

# %%
# Descripción del aluminio y sus respectivas gráficas

description_Al = pd.DataFrame(df.Al.describe())
print('')
print(description_Al.T)
print('')
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
sns.histplot(x='Al', kde=True, data=df, bins=20, color='gold')
plt.subplot(2,1,2)
sns.boxplot(x='Al', data=df, color='gold')
plt.show()
# Out:
#     count      mean      std   min   25%   50%   75%  max
# Al  214.0  1.444907  0.49927  0.29  1.19  1.36  1.63  3.5

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 1.44 %.</li>
#     <br>
#     <li>La distribución posee un desvío estándar de 0.499 aprox. Se visualiza una tendencia sesgada levemente hacia la derecha tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 1.36 %.</li>
#     <br>
#     <li>Observemos que existen varios outliers en esta variable.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Si: Silicio 👈</h3>

# %%
# Descripción del silicio y sus respectivas gráficas

description_Si = pd.DataFrame(df.Si.describe())
print('')
print(description_Si.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2,1,1)
sns.histplot(x='Si', kde=True, data=df, bins=20, color='green')
plt.subplot(2,1,2)
sns.boxplot(x='Si', data=df, color='green')
plt.show()
# Out:
#     count       mean       std    min    25%    50%      75%    max
# Si  214.0  72.650935  0.774546  69.81  72.28  72.79  73.0875  75.41

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 72.65 %.</li>
#     <br>
#     <li>La distribución posee un desvío estándar de 0.77 aprox. Se visualiza una tendencia sesgada levemente hacia la izquierda tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 72.79 %.</li>
#     <br>
#     <li>Observemos que existen varios outliers en esta variable.</li>

# %% [markdown]
# <br>
# <h3 align='center'>K: Potasio 👈</h3>

# %%
# Descripción del potasio y sus respectivas gráficas

description_K = pd.DataFrame(df.K.describe())
print('')
print(description_K.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2,1,1)
sns.histplot(x='K', kde=True, data=df, bins=20, color='darkorange')
plt.subplot(2,1,2)
sns.boxplot(x='K', data=df, color='darkorange')
plt.show()
# Out:
#    count      mean       std  min     25%    50%   75%   max
# K  214.0  0.497056  0.652192  0.0  0.1225  0.555  0.61  6.21

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 0.49 %.</li>
#     <br>
#     <li>La distribución un desvío estándar de 0.65 aprox. Se visualiza claramente una tendencia sesgada hacia la izquierda tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 0.55 %.</li>
#     <br>
#     <li>Observemos que no hay muchos outliers en esta variable.</li>

# %% [markdown]
# <br>
# <h3 align='center'>Ca: Calcio 👈</h3>

# %%
# Descripción del calcio y sus respectivas gráficas

description_Ca = pd.DataFrame(df.Ca.describe())
print('')
print(description_Ca.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2, 1, 1)
sns.histplot(x='Ca', kde=True, data=df, bins=20, color='goldenrod')
plt.subplot(2, 1, 2)
sns.boxplot(x='Ca', data=df, color='goldenrod')
plt.show()
# Out:
#     count      mean       std   min   25%  50%     75%    max
# Ca  214.0  8.956963  1.423153  5.43  8.24  8.6  9.1725  16.19

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 8.95 % aproximadamente.</li>
#     <br>
#     <li>La distribución posee un desvío estándar de 0.499 aprox. Se visualiza una tendencia sesgada levemente hacia la derecha tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 8.6 %.</li>
#     <br>
#     <li>Observemos que existen varios outliers en esta variable.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Ba: Bario 👈</h3>

# %%
# Descripción del bario y sus respectivas gráficas

description_Ba = pd.DataFrame(df.Ba.describe())
print('')
print(description_Ba.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2,1,1)
sns.histplot(x='Ba', kde=True, data=df, bins=20, color='goldenrod')
plt.subplot(2,1,2)
sns.boxplot(x='Ba', data=df, color='goldenrod')
plt.show()
# Out:
#     count      mean       std  min  25%  50%  75%   max
# Ba  214.0  0.175047  0.497219  0.0  0.0  0.0  0.0  3.15

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 0.17 % aproximadamente.</li>
#     <br>
#     <li>La distribución posee un desvío estándar de 0.497 aprox. Se visualiza claramente una tendencia sesgada hacia la derecha tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 0 %.</li>
#     <br>
#     <li>Observemos que existen varios outliers en esta variable, es por eso que la media esta desplazada hacia la derecha del 0 %.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Fe: Hierro 👈</h3>

# %%
# Descripción del hierro y sus respectivas gráficas

description_Fe = pd.DataFrame(df.Fe.describe())
print('')
print(description_Fe.T)
print('')
plt.figure(figsize=(20, 10))
plt.subplot(2,1,1)
sns.histplot(x='Fe', kde=True, data=df, bins=20, color='greenyellow')
plt.subplot(2,1,2)
sns.boxplot(x='Fe', data=df, color='greenyellow')
plt.show()
# Out:
#     count      mean       std  min  25%  50%  75%   max
# Fe  214.0  0.057009  0.097439  0.0  0.0  0.0  0.1  0.51

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>La media es del 0.05 % aproximadamente.</li>
#     <br>
#     <li>La distribución posee un desvío estándar de 0.09 aprox. Se visualiza claramente una tendencia sesgada hacia la derecha tanto en el boxplot como en el histograma.</li>
#     <br>
#     <li>La mediana se encuentra cerca del 0 %.</li>
#     <br>
#     <li>Observemos que existen varios outliers en esta variable, es por eso que la media esta desplazada hacia la derecha del 0 %.</li>
# </p>

# %% [markdown]
# <br>
# <h3 align='center'>Types: Tipos 👈</h3>

# %%
# Mostramos que tipos de vidrio se encuentran en el dataset y la cantidad de los mismos

plt.figure(figsize=(20,10))
sns.countplot(x='Type', data=df, palette='Spectral')
plt.show()

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>Vemos una predominancia casi total de los tipos 1 y 2</li>
#     <li>No se registraron datos de tipo 4</li>
#     <li>El tipo 6 es el que menos se registró</li>
# </p>
# <br>
# <br>

# %% [markdown]
# <h4 align="center">Predominancia de cada tipo sobre cada elemento químico</h4>

# %%
plt.figure(figsize=(22,40))

# Creamos una lista que contenga el indice de refracción y los elementos químicos a iterar
cols = ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe']

# Para la visualización creamos 9 subplot 
for col in cols:
    plt.subplot(5, 2, cols.index(col)+1)
    sns.histplot(data=df, x=col, element='poly', hue='Type', bins=6, palette='Spectral')
    plt.title('Feature ('+str(col)+') por tipos', fontdict={'fontsize': 18})
plt.show()

# %% [markdown]
# <h4 align="center">Observaciones 🕵️​ </h4>
# <p>
#     <li>Como explicamos anteriormente, vemos esa predominancia casi total en todos los features de los tipos 1 y 2</li>
#     <br>
# </p>

# %% [markdown]
# <br>
# <h3 align="center">Matriz de correlación 👈</h3>

# %%
# Creamos una heatmap con la matriz de correlación del dataset

plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, linewidths=.5, cmap='YlGnBu')
plt.show()
